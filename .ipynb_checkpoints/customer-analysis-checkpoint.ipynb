# %% [markdown]
# # Technical Test @LeKiosk

# %% [markdown]
# ###### Explorer le dataset «testDS_dataset»avec l’outil Python et décrire les données trouvées. Ce dataset contient des lectures de magazines ou journaux. Proposer une analyse sur les habitudes de lecture des utilisateurs selon qu’ils utilisent une tablette ou untéléphone mobile. Livrable: code écrit et analyse présentée sur 1 slide.

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import LabelEncoder

# %matplotlib inline
mpl.style.use('ggplot')

# %%
data = pd.read_csv("testDS_dataset.csv")

# %%
data
# Out:
#        IdUser                                   LabelPublication  device  \
# 0           0                                             Octane  tablet
# 1           0                                             Octane  tablet
# 2           0                           Cuisine a & d Hors Série  tablet
# 3           0                                             Octane  tablet
# 4           0                                             Octane  tablet
# 5           0                                             Octane  tablet
# 6           0                                            So Foot  tablet
# 7           0                                            So Foot  tablet
# 8           0                                  Désirs de Voyages  tablet
# 9           0                                  Grands Reportages  tablet
# 10          0                           Maxi Hors Série Tourisme  tablet
# 11          0                                      Suv Crossover  tablet
# 12          0                           Voyages & Hôtels de rêve  tablet
# 13          0               Voyages et Hôtels de rêve Hors Série  tablet
# 14          0                              Sport Auto Hors-Série  tablet
# 15          0                              Sport Auto Hors-Série  tablet
# 16          0                            4x4 magazine Hors-Série  tablet
# 17          0                                         Fantasia 7  tablet
# 18          0                            Midi Olympique Magazine  tablet
# 19          0                                     Rugby magazine  tablet
# 20          0             Je Lis des Histoires Vraies Hors Série  tablet
# 21          0                                    Picsou magazine  tablet
# 22          0                                                Lui  tablet
# 23          0                                     Rugby magazine  tablet
# 24          0                                      Suv Crossover  tablet
# 25          0                                                Lui  tablet
# 26          0                                                Lui  tablet
# 27          0             Je Lis des Histoires Vraies Hors Série  tablet
# 28          0                                                Lui  tablet
# 29          0                                       4x4 magazine  tablet
# ...       ...                                                ...     ...
# 93167    2646                                      Jardin Facile  tablet
# 93168    2646                                            Rustica  tablet
# 93169    2646  L'Ami des Jardins Hors-Série " Les Best Sellers "  tablet
# 93170    2646                                 Marie Claire Idées  tablet
# 93171    2646                                   Ideat Hors Série  tablet
# 93172    2646                                          Le Revenu  tablet
# 93173    2646                                          Le Revenu  tablet
# 93174    2646                                       Entreprendre  tablet
# 93175    2646                                          Le Revenu  tablet
# 93176    2646                                      Mag in France  tablet
# 93177    2646                                                ASH  tablet
# 93178    2646                                   Forêt Entreprise  tablet
# 93179    2646                                         Stratégies  tablet
# 93180    2646                                    Santé Naturelle  tablet
# 93181    2646                               Top Santé Hors-Série  tablet
# 93182    2646                                    Garçon Magazine  tablet
# 93183    2646                                    Garçon Magazine  tablet
# 93184    2646                                    Garçon Magazine  tablet
# 93185    2646                                             Public  tablet
# 93186    2646                                         Agefi Life  tablet
# 93187    2646                                         Agefi Life  tablet
# 93188    2646                                         Agefi Life  tablet
# 93189    2646  L'Ami des Jardins Hors-Série " Les Best Sellers "  tablet
# 93190    2646                                 Marie Claire Idées  tablet
# 93191    2646                                      Spécial Chats  tablet
# 93192    2646                                    Elle Décoration  tablet
# 93193    2646                                          Le Revenu  tablet
# 93194    2646                             L'Univers de la Maison  tablet
# 93195    2646                             L'Univers de la Maison  tablet
# 93196    2646                                Maisons de Campagne  tablet
#
#                  Category                date  hour  minute  sessions  \
# 0             Auto & Moto  2018-11-02 0:00:00    18      35         1
# 1             Auto & Moto  2018-11-02 0:00:00    18      35         1
# 2                 Cuisine  2018-11-02 0:00:00    18      38         1
# 3             Auto & Moto  2018-11-02 0:00:00    18      34         1
# 4             Auto & Moto  2018-11-02 0:00:00    18      32         1
# 5             Auto & Moto  2018-11-02 0:00:00    18      33         1
# 6                  Sports  2018-11-02 0:00:00    18      35         1
# 7                  Sports  2018-11-02 0:00:00    18      36         1
# 8                 Voyages  2018-11-02 0:00:00    18      45         1
# 9                 Voyages  2018-11-02 0:00:00    18      41         1
# 10                Voyages  2018-11-02 0:00:00    18      42         1
# 11            Auto & Moto  2018-11-02 0:00:00    18      46         1
# 12                Voyages  2018-11-02 0:00:00    18      40         1
# 13                Voyages  2018-11-02 0:00:00    18      44         1
# 14            Auto & Moto  2018-11-02 0:00:00    18      58         1
# 15            Auto & Moto  2018-11-02 0:00:00    18      57         1
# 16            Auto & Moto  2018-11-02 0:00:00    19       3         1
# 17              Activités  2018-11-02 0:00:00    19       8         1
# 18                 Sports  2018-11-02 0:00:00    19       0         1
# 19                 Sports  2018-11-02 0:00:00    19       1         1
# 20               Jeunesse  2018-11-02 0:00:00    19      12         1
# 21               Jeunesse  2018-11-02 0:00:00    19      11         1
# 22               Masculin  2018-11-04 0:00:00    17      38         1
# 23                 Sports  2018-11-04 0:00:00    19      28         1
# 24            Auto & Moto  2018-11-04 0:00:00    19      26         1
# 25               Masculin  2018-11-04 0:00:00    21      28         1
# 26               Masculin  2018-11-04 0:00:00    21      31         1
# 27               Jeunesse  2018-11-04 0:00:00    21      40         1
# 28               Masculin  2018-11-04 0:00:00    21      41         1
# 29            Auto & Moto  2018-11-10 0:00:00    15      37         1
# ...                   ...                 ...   ...     ...       ...
# 93167              Maison  2018-11-10 0:00:00     1      14         1
# 93168              Maison  2018-11-10 0:00:00     1      14         1
# 93169              Maison  2018-11-10 0:00:00     1      24         1
# 93170           Activités  2018-11-10 0:00:00     1      26         1
# 93171       Déco & Design  2018-11-10 0:00:00     1      34         1
# 93172  Presse spécialisée  2018-11-10 0:00:00    14      54         1
# 93173  Presse spécialisée  2018-11-10 0:00:00    14      58         1
# 93174  Presse spécialisée  2018-11-10 0:00:00    15       7         1
# 93175  Presse spécialisée  2018-11-10 0:00:00    15       1         1
# 93176  Presse spécialisée  2018-11-10 0:00:00    15      17         1
# 93177  Presse spécialisée  2018-11-10 0:00:00    15      23         1
# 93178  Presse spécialisée  2018-11-10 0:00:00    15      22         1
# 93179  Presse spécialisée  2018-11-10 0:00:00    15      28         1
# 93180           Bien-être  2018-11-15 0:00:00    23      57         1
# 93181           Bien-être  2018-11-15 0:00:00    23      58         1
# 93182            Masculin  2018-11-16 0:00:00     0       7         1
# 93183            Masculin  2018-11-16 0:00:00     0       8         1
# 93184            Masculin  2018-11-16 0:00:00     0      11         1
# 93185         People & TV  2018-11-16 0:00:00     0      10         1
# 93186       Déco & Design  2018-11-16 0:00:00     0      23         1
# 93187       Déco & Design  2018-11-16 0:00:00     0      24         1
# 93188       Déco & Design  2018-11-16 0:00:00     0      25         1
# 93189              Maison  2018-11-16 0:00:00     0      22         1
# 93190           Activités  2018-11-16 0:00:00     0      22         1
# 93191             Animaux  2018-11-22 0:00:00    21      53         1
# 93192       Déco & Design  2018-11-22 0:00:00    22       1         1
# 93193  Presse spécialisée  2018-11-24 0:00:00    11      37         1
# 93194       Déco & Design  2018-11-25 0:00:00     0      33         1
# 93195       Déco & Design  2018-11-25 0:00:00     0      52         1
# 93196       Déco & Design  2018-11-25 0:00:00     1       2         1
#
#        sessionDuration  avgSessionDuration
# 0                 3751              3751.0
# 1                 3751              3751.0
# 2                 3751              3751.0
# 3                 3751              3751.0
# 4                 3751              3751.0
# 5                 3751              3751.0
# 6                 3751              3751.0
# 7                 3751              3751.0
# 8                 3751              3751.0
# 9                 3751              3751.0
# 10                3751              3751.0
# 11                3751              3751.0
# 12                3751              3751.0
# 13                3751              3751.0
# 14                3751              3751.0
# 15                3751              3751.0
# 16                3751              3751.0
# 17                3751              3751.0
# 18                3751              3751.0
# 19                3751              3751.0
# 20                3751              3751.0
# 21                3751              3751.0
# 22                 441               441.0
# 23                 188               188.0
# 24                 188               188.0
# 25                2122              2122.0
# 26                2122              2122.0
# 27                2122              2122.0
# 28                2122              2122.0
# 29                1025              1025.0
# ...                ...                 ...
# 93167             5261              5261.0
# 93168             5261              5261.0
# 93169             5261              5261.0
# 93170             5261              5261.0
# 93171             5261              5261.0
# 93172             3635              3635.0
# 93173             3635              3635.0
# 93174             3635              3635.0
# 93175             3635              3635.0
# 93176             3635              3635.0
# 93177             3635              3635.0
# 93178             3635              3635.0
# 93179             3635              3635.0
# 93180              257               257.0
# 93181              257               257.0
# 93182             1628              1628.0
# 93183             1628              1628.0
# 93184             1628              1628.0
# 93185             1628              1628.0
# 93186             1628              1628.0
# 93187             1628              1628.0
# 93188             1628              1628.0
# 93189             1628              1628.0
# 93190             1628              1628.0
# 93191             2418              2418.0
# 93192             2418              2418.0
# 93193              999               999.0
# 93194             2866              2866.0
# 93195             2866              2866.0
# 93196             2866              2866.0
#
# [93197 rows x 10 columns]

# %% [markdown]
# ## Data Exploration

# %%
# Creating a copy of original data
data1 = data.copy(deep = True)
data1 = pd.DataFrame(data1)

# First look at data
print (data1.info())
print ("-" * 10)
data1.describe(include = 'all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93197 entries, 0 to 93196
# Data columns (total 10 columns):
# IdUser                93197 non-null int64
# LabelPublication      93197 non-null object
# device                93197 non-null object
# Category              93084 non-null object
# date                  93197 non-null object
# hour                  93197 non-null int64
# minute                93197 non-null int64
# sessions              93197 non-null int64
# sessionDuration       93197 non-null int64
# avgSessionDuration    93197 non-null float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 7.1+ MB
# None
# ----------
#               IdUser LabelPublication  device     Category  \
# count   93197.000000            93197   93197        93084
# unique           NaN             1470       2           21
# top              NaN      Paris Match  tablet  People & TV
# freq             NaN             2644   72173        12071
# mean     1324.208987              NaN     NaN          NaN
# std       770.703061              NaN     NaN          NaN
# min         0.000000              NaN     NaN          NaN
# 25%       638.000000              NaN     NaN          NaN
# 50%      1337.000000              NaN     NaN          NaN
# 75%      1996.000000              NaN     NaN          NaN
# max      2646.000000              NaN     NaN          NaN
#
#                       date          hour        minute      sessions  \
# count                93197  93197.000000  93197.000000  93197.000000
# unique                  30           NaN           NaN           NaN
# top     2018-11-25 0:00:00           NaN           NaN           NaN
# freq                  4138           NaN           NaN           NaN
# mean                   NaN     13.668991     29.221885      1.000172
# std                    NaN      6.597767     17.212183      0.018529
# min                    NaN      0.000000      0.000000      1.000000
# 25%                    NaN      8.000000     14.000000      1.000000
# 50%                    NaN     14.000000     30.000000      1.000000
# 75%                    NaN     20.000000     44.000000      1.000000
# max                    NaN     23.000000     58.000000      3.000000
#
#         sessionDuration  avgSessionDuration
# count      93197.000000        93197.000000
# unique              NaN                 NaN
# top                 NaN                 NaN
# freq                NaN                 NaN
# mean        2450.140037         2449.816242
# std         2639.717619         2639.136828
# min            0.000000            0.000000
# 25%          556.000000          556.000000
# 50%         1684.000000         1684.000000
# 75%         3436.000000         3436.000000
# max        25239.000000        25239.000000

# %% [markdown]
# * This data was fetched during the month of November
# * On average, users spend about 42 minutes per session
# * Most people read on their tablet
# * The most read magazine is Paris Match
# * The most read category is People & TV

# %%
# Replace NaN in 'Category'

data1['Category'].fillna('Misc', inplace = True)

# Number of users per Category 

category_id = data1["IdUser"].groupby(data1["Category"]).sum()

# Sort by most popular Categories

category_id.sort_values(ascending=False, inplace=True)

# Convert to percentages

category_id = (100. * category_id / category_id.sum()).round(0)
category_id.head(5)
# Out:
# Category
# People & TV    12.0
# Actualités     12.0
# Quotidiens     11.0
# Auto & Moto     9.0
# Féminin         6.0
# Name: IdUser, dtype: float64

# %%
plt.figure(figsize=[25,20])

category_id.plot.bar()
plt.title('Percentage of total users per Category')
plt.ylabel('percentage of users')
plt.legend()

# %%
# Compute the number of sessions per user

session_id = data1["sessions"].groupby(data1["IdUser"]).sum()
print (session_id.head(10))
print ('-' * 10)
print (session_id.describe(include='all'))
# Out:
# IdUser
# 0    143
# 1      8
# 2     82
# 3     78
# 4     10
# 5     18
# 6     30
# 7     13
# 8     29
# 9     30
# Name: sessions, dtype: int64
# ----------
# count    2647.000000
# mean       35.214583
# std        47.616143
# min         1.000000
# 25%         7.000000
# 50%        19.000000
# 75%        45.000000
# max       640.000000
# Name: sessions, dtype: float64

# %% [markdown]
# * On average, users open 35 sessions during the month of November. Looking at the time of sessions' openings (i.e. 'hour' & 'minute'), it seems users can open many sessions at the same time.

# %% [markdown]
# ## Split by devices

# %%
data_t = data1[data1['device'] == 'tablet']
data_m = data1[data1['device'] == 'mobile']

# %%
data_t.describe(include = 'all')
# Out:
#               IdUser LabelPublication  device     Category  \
# count   72173.000000            72173   72173        72173
# unique           NaN             1404       1           22
# top              NaN      Paris Match  tablet  People & TV
# freq             NaN             2129   72173         9490
# mean     1335.661051              NaN     NaN          NaN
# std       776.430909              NaN     NaN          NaN
# min         0.000000              NaN     NaN          NaN
# 25%       638.000000              NaN     NaN          NaN
# 50%      1355.000000              NaN     NaN          NaN
# 75%      2020.000000              NaN     NaN          NaN
# max      2646.000000              NaN     NaN          NaN
#
#                       date          hour        minute      sessions  \
# count                72173  72173.000000  72173.000000  72173.000000
# unique                  30           NaN           NaN           NaN
# top     2018-11-25 0:00:00           NaN           NaN           NaN
# freq                  3446           NaN           NaN           NaN
# mean                   NaN     13.797791     29.204897      1.000222
# std                    NaN      6.639072     17.219521      0.021056
# min                    NaN      0.000000      0.000000      1.000000
# 25%                    NaN      8.000000     14.000000      1.000000
# 50%                    NaN     15.000000     30.000000      1.000000
# 75%                    NaN     20.000000     44.000000      1.000000
# max                    NaN     23.000000     58.000000      3.000000
#
#         sessionDuration  avgSessionDuration
# count      72173.000000        72173.000000
# unique              NaN                 NaN
# top                 NaN                 NaN
# freq                NaN                 NaN
# mean        2617.237471         2616.819355
# std         2726.410735         2725.710214
# min            0.000000            0.000000
# 25%          667.000000          667.000000
# 50%         1850.000000         1849.000000
# 75%         3673.000000         3673.000000
# max        25239.000000        25239.000000

# %% [markdown]
# * 77% of users are tablet readers
# * Their average reading time is 44 minutes per session, which is slightly more than for the whole population
# * Paris Match is their favorite magazine, which is represented in the total population

# %%
data_m.describe(include = 'all')
# Out:
#               IdUser LabelPublication  device    Category                date  \
# count   21024.000000            21024   21024       21024               21024
# unique           NaN              995       1          22                  30
# top              NaN      Le Parisien  mobile  Quotidiens  2018-11-02 0:00:00
# freq             NaN              995   21024        3138                 891
# mean     1284.895358              NaN     NaN         NaN                 NaN
# std       749.395214              NaN     NaN         NaN                 NaN
# min         4.000000              NaN     NaN         NaN                 NaN
# 25%       629.000000              NaN     NaN         NaN                 NaN
# 50%      1280.000000              NaN     NaN         NaN                 NaN
# 75%      1946.000000              NaN     NaN         NaN                 NaN
# max      2645.000000              NaN     NaN         NaN                 NaN
#
#                 hour        minute  sessions  sessionDuration  \
# count   21024.000000  21024.000000   21024.0     21024.000000
# unique           NaN           NaN       NaN              NaN
# top              NaN           NaN       NaN              NaN
# freq             NaN           NaN       NaN              NaN
# mean       13.226836     29.280204       1.0      1876.513556
# std         6.434531     17.187252       0.0      2224.065434
# min         0.000000      0.000000       1.0         1.000000
# 25%         8.000000     14.000000       1.0       320.000000
# 50%        13.000000     30.000000       1.0      1157.000000
# 75%        19.000000     44.000000       1.0      2587.000000
# max        23.000000     58.000000       1.0     15661.000000
#
#         avgSessionDuration
# count         21024.000000
# unique                 NaN
# top                    NaN
# freq                   NaN
# mean           1876.513556
# std            2224.065434
# min               1.000000
# 25%             320.000000
# 50%            1157.000000
# 75%            2587.000000
# max           15661.000000

# %% [markdown]
# * 23% of readers are mobile users
# * Their average reading time per session is 31 minutes, 10 min less than tablet readers. This is linked to the fact that tablets are more appropriate and confortable as a reading device
# * Their favorite journal is Le Parisien, and their favorite category is 'Quotidiens' journals.

# %% [markdown]
# #### Time spent split by devices

# %%
#time spent per session on tablet
session_id_t = data_t["sessions"].groupby(data_t["IdUser"]).sum()
print ('sessions opened per tablet user:')
print (session_id_t.describe(include='all'))
print ('-' * 10)

#time spent per session on mobile
session_id_m = data_m["sessions"].groupby(data_m["IdUser"]).sum()
print ('sessions opened per mobile user:')
print (session_id_m.describe(include='all'))
# Out:
# sessions opened per tablet user:
# count    1941.000000
# mean       37.191654
# std        49.018063
# min         1.000000
# 25%         8.000000
# 50%        21.000000
# 75%        47.000000
# max       589.000000
# Name: sessions, dtype: float64
# ----------
# sessions opened per mobile user:
# count    1156.000000
# mean       18.186851
# std        29.098305
# min         1.000000
# 25%         3.000000
# 50%         8.000000
# 75%        21.250000
# max       320.000000
# Name: sessions, dtype: float64

# %% [markdown]
# * Tablet users opened 37 sessions on average during November, whereas mobile users opened half as much

# %%
plt.figure(figsize=[20,16])

plt.subplot(234)
plt.hist(x = [data1[data1['device']=='tablet']['avgSessionDuration'], 
        data1[data1['device']=='mobile']['avgSessionDuration']], 
        stacked=True, color = ['g','r'],label = ['tablet','mobile'])
plt.title('Average Session Duration by device')
plt.xlabel('Average Session Duration in seconds')
plt.ylabel('# of users')
plt.legend()

# %% [markdown]
# #### Categories split by device

# %%
# Number of users per Category for Tablet Users
category_id_t = data_t["IdUser"].groupby(data_t["Category"]).sum()
category_id_t.sort_values(ascending=False, inplace=True)
category_id_t = (100. * category_id_t / category_id_t.sum()).round(0)

# Number of users per Category for Mobile Users
category_id_m = data_m["IdUser"].groupby(data_m["Category"]).sum()
category_id_m.sort_values(ascending=False, inplace=True)
category_id_m = (100. * category_id_m / category_id_m.sum()).round(0)

# %%
category_id_t
# Out:
# Category
# People & TV           13.0
# Actualités            12.0
# Quotidiens            11.0
# Auto & Moto           10.0
# Féminin                6.0
# Masculin               6.0
# Technologie            5.0
# Déco & Design          5.0
# Activités              5.0
# Culture                4.0
# Cuisine                4.0
# Savoirs                3.0
# Turf                   3.0
# Sports                 2.0
# Presse spécialisée     2.0
# Bien-être              2.0
# Jeunesse               2.0
# Voyages                1.0
# Maison                 1.0
# Internationaux         1.0
# Animaux                0.0
# Misc                   0.0
# Name: IdUser, dtype: float64

# %%
category_id_m
# Out:
# Category
# Quotidiens            14.0
# Actualités            14.0
# People & TV           11.0
# Auto & Moto            7.0
# Féminin                7.0
# Turf                   6.0
# Masculin               5.0
# Culture                4.0
# Technologie            4.0
# Déco & Design          4.0
# Sports                 3.0
# Activités              3.0
# Cuisine                3.0
# Presse spécialisée     3.0
# Savoirs                3.0
# Bien-être              3.0
# Internationaux         2.0
# Jeunesse               1.0
# Maison                 1.0
# Voyages                1.0
# Animaux                0.0
# Misc                   0.0
# Name: IdUser, dtype: float64

# %%
plt.figure(figsize=[25,20])

plt.subplot(235)
category_id_t.plot.bar()
plt.title('Number of Tablet users per Category')
plt.ylabel('number of users')
plt.legend()

plt.subplot(236)
category_id_m.plot.bar()
plt.title('Number of Mobile users per Category')
plt.ylabel('number of users')
plt.legend()
